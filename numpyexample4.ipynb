# %%
from PIL import Image
import numpy as np

array=np.zeros([5,4,3],dtype='uint8')
array
# array[:,(0,1)]=10 # row Wise
# array[:,:,(1,2)]=10 # column wise
# array[:,:]=[255,165,0]
#Black
ar_black=array.copy()
ar_dimgray=array.copy()
ar_gray=array.copy()
ar_darkgray=array.copy()
ar_silver=array.copy()



#Blue

ar_aliceblue=array.copy()
ar_lavender=array.copy()
ar_powderblue=array.copy()
ar_lightblue=array.copy()
ar_lightskyblue=array.copy()
ar_skyblue=array.copy()
ar_deepskyblue=array.copy()
ar_lightsteelblue=array.copy()
ar_dodgerblue=array.copy()
ar_cornflowerblue=array.copy()
ar_steelblue=array.copy()
ar_cadetblue=array.copy()
ar_mediumslateblue=array.copy()
ar_slateblue=array.copy()
ar_darkslateblue=array.copy()
ar_royalblue=array.copy()
ar_blue=array.copy()
ar_mediumblue=array.copy()
ar_darkblue=array.copy()
ar_navy=array.copy()
ar_midnightblue=array.copy()
ar_blueviolet=array.copy()
ar_ndigo=array.copy()


ar_black[:,:,(0,1,2)]=[0,0,0]
ar_dimgray[:,:,(0,1,2)]=[105,105,105]
ar_gray[:,:,(0,1,2)]=[128,128,128]
ar_darkgray[:,:,(0,1,2)]=[169,169,169]
ar_silver[:,:,(0,1,2)]=[192,192,192]


#Blue
ar_aliceblue[:,:,(0,1,2)]=[240,248,255]
ar_lavender[:,:,(0,1,2)]=[230,230,250]
ar_powderblue[:,:,(0,1,2)]=[176,224,230]
ar_lightblue[:,:,(0,1,2)]=[173,216,230]
ar_lightskyblue[:,:,(0,1,2)]=[135,206,250]
ar_skyblue[:,:,(0,1,2)]=[125,206,235]
ar_deepskyblue[:,:,(0,1,2)]=[0,191,255]
ar_lightsteelblue[:,:,(0,1,2)]=[176,192,222]
ar_dodgerblue[:,:,(0,1,2)]=[30,144,255]
ar_cornflowerblue[:,:,(0,1,2)]=[100,149,237]
ar_steelblue[:,:,(0,1,2)]=[70,130,180]
ar_cadetblue[:,:,(0,1,2)]=[95,158,160]
ar_mediumslateblue[:,:,(0,1,2)]=[123,104,238]
ar_slateblue[:,:,(0,1,2)]=[106,90,205]
ar_darkslateblue[:,:,(0,1,2)]=[72,61,139]
ar_royalblue[:,:,(0,1,2)]=[65,105,225]
ar_blue[:,:,(0,1,2)]=[0,0,255]
ar_mediumblue[:,:,(0,1,2)]=[0,0,205]
ar_darkblue[:,:,(0,1,2)]=[0,0,139]
ar_navy[:,:,(0,1,2)]=[0,0,128]
ar_midnightblue[:,:,(0,1,2)]=[25,25,112]
ar_blueviolet[:,:,(0,1,2)]=[138,43,226]
ar_ndigo[:,:,(0,1,2)]=[75,0,130]


#Brown

ar_cornsilk=array.copy()
ar_blanchedalmond=array.copy()
ar_bisque=array.copy()
ar_navajowhite=array.copy()
ar_wheat=array.copy()
ar_burlywood=array.copy()
ar_tan=array.copy()
ar_rosybrown=array.copy()
ar_sandybrown=array.copy()
ar_goldenrod=array.copy()
ar_peru=array.copy()
ar_chocolate=array.copy()
ar_saddlebrown=array.copy()
ar_sienna=array.copy()
ar_brown=array.copy()
ar_maroon=array.copy()

ar_cornsilk[:,:,(0,1,2)]=[255,248,220]
ar_blanchedalmond[:,:,(0,1,2)]=[255,235,205]
ar_bisque[:,:,(0,1,2)]=[255,228,196]
ar_navajowhite[:,:,(0,1,2)]=[255,222,173]
ar_wheat[:,:,(0,1,2)]=[245,222,179]
ar_burlywood[:,:,(0,1,2)]=[222,184,135]
ar_tan[:,:,(0,1,2)]=[210,180,140]
ar_rosybrown[:,:,(0,1,2)]=[188,143,143]
ar_sandybrown[:,:,(0,1,2)]=[244,164,96]
ar_goldenrod[:,:,(0,1,2)]=[218,165,32]
ar_peru[:,:,(0,1,2)]=[205,133,63]
ar_chocolate[:,:,(0,1,2)]=[210,105,30]
ar_saddlebrown[:,:,(0,1,2)]=[139,69,19]
ar_sienna[:,:,(0,1,2)]=[160,82,45]
ar_brown[:,:,(0,1,2)]=[160,42,42]
ar_maroon[:,:,(0,1,2)]=[128,0,0]
#Cyan

ar_lightcyan=array.copy()
ar_cyan=array.copy()
ar_aqua=array.copy()
ar_aquamarine=array.copy()
ar_mediumaquamarine=array.copy()
ar_paleturquoise=array.copy()
ar_turquoise=array.copy()
ar_mediumturquoise=array.copy()
ar_darkturquoise=array.copy()
ar_lightseagreen=array.copy()
ar_cadetblue=array.copy()
ar_darkcyan=array.copy()
ar_teal=array.copy()

ar_lightcyan[:,:,(0,1,2)]=[224,255,255]
ar_cyan[:,:,(0,1,2)]=[0,255,255]
ar_aqua[:,:,(0,1,2)]=[0,255,255]
ar_aquamarine[:,:,(0,1,2)]=[127,255,212]
ar_mediumaquamarine[:,:,(0,1,2)]=[102,205,170]
ar_paleturquoise[:,:,(0,1,2)]=[175,238,338]
ar_turquoise[:,:,(0,1,2)]=[64,224,208]
ar_mediumturquoise[:,:,(0,1,2)]=[72,209,204]
ar_darkturquoise[:,:,(0,1,2)]=[0,206,209]
ar_lightseagreen[:,:,(0,1,2)]=[32,178,170]
ar_cadetblue[:,:,(0,1,2)]=[95,158,160]
ar_darkcyan[:,:,(0,1,2)]=[0,139,139]
ar_teal[:,:,(0,1,2)]=[0,128,128]


# Grey

ar_pink=array.copy()
ar_lightpink=array.copy()
ar_hotpink=array.copy()
ar_deeppink=array.copy()
ar_palevioletred=array.copy()
ar_mediumvioletred=array.copy()


ar_pink[:,:,(0,1,2)]=[255,192,203]
ar_lightpink[:,:,(0,1,2)]=[255,182,193]
ar_hotpink[:,:,(0,1,2)]=[255,105,180]
ar_deeppink[:,:,(0,1,2)]=[255,20,247]
ar_palevioletred[:,:,(0,1,2)]=[219,112,147]
ar_mediumvioletred[:,:,(0,1,2)]=[199,21,133]







#Gold
ar_lightgoldenrodyellow=array.copy()
ar_palegoldenrod=array.copy()
ar_khaki=array.copy()
ar_goldenrod=array.copy()
ar_gold=array.copy()
ar_orange=array.copy()
ar_darkorange=array.copy()
ar_peru=array.copy()
ar_chocolate=array.copy()
ar_saddlebrown=array.copy()
ar_sienna=array.copy()

ar_lightgoldenrodyellow[:,:,(0,1,2)]=[250,250,210]
ar_palegoldenrod[:,:,(0,1,2)]=[238,232,170]
ar_khaki[:,:,(0,1,2)]=[240,230,140]
ar_goldenrod[:,:,(0,1,2)]=[218,165,32]
ar_gold[:,:,(0,1,2)]=[255,215,0]
ar_orange[:,:,(0,1,2)]=[255,165,0]
ar_darkorange[:,:,(0,1,2)]=[255,140,0]
ar_peru[:,:,(0,1,2)]=[205,133,63]
ar_chocolate[:,:,(0,1,2)]=[210,105,30]
ar_saddlebrown[:,:,(0,1,2)]=[139,69,19]
ar_sienna[:,:,(0,1,2)]=[160,82,45]

#Green

ar_lawngreen=array.copy()
ar_chartreuse=array.copy()
ar_limegreen=array.copy()
ar_lime=array.copy()
ar_forestgreen=array.copy()
ar_green=array.copy()
ar_darkgreen=array.copy()
ar_greenyellow=array.copy()
ar_yellowgreen=array.copy()
ar_springgreen=array.copy()
ar_mediumspringgreen=array.copy()
ar_lightgreen=array.copy()
ar_palegreen=array.copy()
ar_darkseagreen=array.copy()
ar_mediumseagreen=array.copy()
ar_lightseagreen=array.copy()
ar_seagreen=array.copy()
ar_olive=array.copy()
ar_darkolivegreen=array.copy()
ar_olivedrab=array.copy()



ar_lawngreen[:,:,(0,1,2)]=[124,252,0]
ar_chartreuse[:,:,(0,1,2)]=[127,255,0]
ar_limegreen[:,:,(0,1,2)]=[50,205,50]
ar_lime[:,:,(0,1,2)]=[0,255,0]
ar_forestgreen[:,:,(0,1,2)]=[34,139,34]
ar_green[:,:,(0,1,2)]=[0,128,0]
ar_darkgreen[:,:,(0,1,2)]=[0,100,0]
ar_greenyellow[:,:,(0,1,2)]=[173,255,47]
ar_yellowgreen[:,:,(0,1,2)]=[154,205,50]
ar_springgreen[:,:,(0,1,2)]=[0,255,127]
ar_mediumspringgreen[:,:,(0,1,2)]=[0,250,154]
ar_lightgreen[:,:,(0,1,2)]=[144,238,144]
ar_palegreen[:,:,(0,1,2)]=[152,251,152]
ar_darkseagreen[:,:,(0,1,2)]=[143,188,143]
ar_mediumseagreen[:,:,(0,1,2)]=[60,179,113]
ar_lightseagreen[:,:,(0,1,2)]=[32,178,170]
ar_seagreen[:,:,(0,1,2)]=[46,139,87]
ar_olive[:,:,(0,1,2)]=[128,128,0]
ar_darkolivegreen[:,:,(0,1,2)]=[85,107,47]
ar_olivedrab[:,:,(0,1,2)]=[107,142,35]






img_final=np.hstack([ar_black,ar_dimgray,ar_gray,ar_darkgray,ar_silver,ar_aliceblue,ar_lavender,ar_powderblue,ar_lightblue,ar_lightskyblue,ar_skyblue,ar_skyblue,ar_deepskyblue,ar_lightsteelblue,ar_dodgerblue,ar_cornflowerblue,ar_steelblue,ar_cadetblue,ar_mediumslateblue,ar_slateblue,ar_darkslateblue,ar_royalblue,ar_blue,ar_mediumblue,ar_darkblue,ar_navy,ar_midnightblue,ar_blueviolet,ar_ndigo,
                  ar_cornsilk,ar_blanchedalmond ,ar_bisque,ar_navajowhite,ar_wheat,ar_burlywood,ar_tan,ar_rosybrown,ar_sandybrown,ar_goldenrod,ar_peru,ar_chocolate,ar_saddlebrown,ar_sienna,ar_brown,ar_maroon,
ar_lightcyan,ar_cyan,ar_aqua,ar_aquamarine,ar_mediumaquamarine,ar_paleturquoise,ar_turquoise,ar_mediumturquoise,ar_darkturquoise,ar_lightseagreen,ar_cadetblue,ar_darkcyan,ar_teal
,ar_lightgoldenrodyellow,ar_palegoldenrod,ar_khaki,ar_goldenrod,ar_gold,ar_orange,ar_darkorange,ar_peru,ar_chocolate,ar_saddlebrown,ar_sienna
,ar_lawngreen,ar_chartreuse,ar_limegreen,ar_lime,ar_forestgreen,ar_green,ar_darkgreen,ar_greenyellow,ar_yellowgreen,ar_springgreen,ar_mediumspringgreen,ar_lightgreen,ar_palegreen,
ar_darkseagreen,ar_mediumseagreen,ar_lightseagreen,ar_seagreen,ar_olive,ar_darkolivegreen,ar_olivedrab,
ar_pink,ar_lightpink,ar_hotpink,ar_deeppink,ar_palevioletred,ar_mediumvioletred
]) # horizontal
imgshow=Image.fromarray(img_final)
# # print(imgshow.size)
imgshow
# Out:
# <PIL.Image.Image image mode=RGB size=380x5 at 0x180172CF108>
